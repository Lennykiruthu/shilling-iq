# %%
import pandas as pd 
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

# %%
# Nairobi securities exchange all stock prices 2007-2012

# nse_2007_df = pd.read_csv("/storage/local-git-repos/shilling-iq/Nairobi Securities Exchange All Stocks Prices 2007-2012/NSE_data_all_stocks_2007.csv")
# nse_2008_df = pd.read_csv("/storage/local-git-repos/shilling-iq/Nairobi Securities Exchange All Stocks Prices 2007-2012/NSE_data_all_stocks_2008.csv")
# nse_2009_df = pd.read_csv("/storage/local-git-repos/shilling-iq/Nairobi Securities Exchange All Stocks Prices 2007-2012/NSE_data_all_stocks_2009.csv")
# nse_2010_df = pd.read_csv("/storage/local-git-repos/shilling-iq/Nairobi Securities Exchange All Stocks Prices 2007-2012/NSE_data_all_stocks_2010.csv")
# nse_2011_df = pd.read_csv("/storage/local-git-repos/shilling-iq/Nairobi Securities Exchange All Stocks Prices 2007-2012/NSE_data_all_stocks_2011.csv")
# nse_2012_df = pd.read_csv("/storage/local-git-repos/shilling-iq/Nairobi Securities Exchange All Stocks Prices 2007-2012/NSE_data_all_stocks_2012.csv")

nse_2013_df = pd.read_csv("/storage/local-git-repos/shilling-iq/NSE_data_all_stocks_2013.csv")
# nse_2013_sectors_df = pd.read_csv("/storage/local-git-repos/shilling-iq/NSE_data_stock_market_sectors_2013.csv")

# %%
def Explore(df, title):
    display(Markdown(title))
    display(Markdown("---"))    
    display(df.head(10))
    display(Markdown("### Shape"))
    display(Markdown("---"))    
    display(df.shape)
    display(Markdown("### Missing values"))
    display(Markdown("---"))    
    display(df.isnull().sum())    
    display(Markdown("### Unique Counts Per Column"))
    display(Markdown("---"))    
    display(df.nunique())
    display(Markdown("### Date Types"))
    display(Markdown("---"))    
    display(df.dtypes)    

Explore(nse_2013_df, "## NSE 2009 Data")
# Out:
# ## NSE 2009 Data
# ---
#        DATE  CODE                            NAME 12m Low 12m High Day Low  \
# 0  2-Jan-13  EGAD                     Eaagads Ltd     8.2       14      25
# 1  2-Jan-13  KUKZ                      Kakuzi Plc     300    423.5    67.5
# 2  2-Jan-13  KAPC         Kapchorua Tea Kenya Plc      59       95     118
# 3  2-Jan-13  LIMT                  Limuru Tea Plc     385      475     430
# 4  2-Jan-13  SASN                      Sasini Plc    14.8     19.6    11.7
# 5  2-Jan-13   WTK        Williamson Tea Kenya Plc      92      165     200
# 6  2-Jan-13  CGEN         Car and General (K) Ltd      20       26      24
# 7  2-Jan-13  ABSA             ABSA Bank Kenya Plc     9.3     14.2   15.65
# 8  2-Jan-13  COOP  Co-operative Bank of Kenya Ltd    10.5       17   12.75
# 9  2-Jan-13   DTK    Diamond Trust Bank Kenya Ltd   67.75      127     118
#
#   Day High Day Price Previous Change Change%   Volume  Adjust
# ...

# %%
del nse_2007_df
